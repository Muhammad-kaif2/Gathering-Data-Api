# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-kaif2/Gathering-Data-Api/blob/main/Fetch_Api_all_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Fetch which tpe of data

# %%
import pandas as pd
import requests
response = requests.get("https://jsonplaceholder.typicode.com/posts")
content_type = response.headers.get('Content-Type')
print( content_type)
# Out:
# application/json; charset=utf-8

# %% [markdown]
# XML data

# %%
import requests
import xml.etree.ElementTree as ET

url = "https://www.w3schools.com/xml/note.xml"
response = requests.get(url)

# Parse XML
root = ET.fromstring(response.text)
print("XML Data:")
for child in root:
    print(child.tag, ":", child.text)
# Out:
# XML Data:
# to : Tove
# from : Jani
# heading : Reminder
# body : Don't forget me this weekend!

# %% [markdown]
# CSV data

# %%
import requests
import pandas as pd
from io import StringIO

url = "https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv"
response = requests.get(url)

# Convert CSV text to DataFrame
df = pd.read_csv(StringIO(response.text))
df
# Out:
#      Index   Height(Inches)"   "Weight(Pounds)"
# 0        1             65.78             112.99
# 1        2             71.52             136.49
# 2        3             69.40             153.03
# 3        4             68.22             142.34
# 4        5             67.79             144.30
# ..     ...               ...                ...
# 195    196             65.80             120.84
# 196    197             66.11             115.78
# 197    198             68.24             128.30
# 198    199             68.02             127.47
# 199    200             71.39             127.88
#
# [200 rows x 3 columns]

# %% [markdown]
# JSON data

# %%
import requests

url = "https://jsonplaceholder.typicode.com/todos/1"
response = requests.get(url)

# Convert response to Python dict
data = response.json()
print("JSON Data:", data)
# Out:
# JSON Data: {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %%
r = requests.get("https://jsonplaceholder.typicode.com/posts")
df = pd.DataFrame(r.json())
df.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %% [markdown]
# Text data

# %%
url = "https://api.github.com/zen"
response = requests.get(url)

print("Plain Text:", response.text)
# Out:
# Plain Text: Half measures are as bad as nothing at all.

# %% [markdown]
# HTML data

# %%
import requests
from bs4 import BeautifulSoup

url = "https://example.com"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")
print("HTML Title:", soup.title.text)
# Out:
# HTML Title: Example Domain
